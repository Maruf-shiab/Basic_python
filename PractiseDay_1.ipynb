# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruf-shiab/Basic_python/blob/main/PractiseDay_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("what is your name?")
print(name)

# %%
name =("what is your age")

# %%
a=5
b=6
a+b

# %%
print(a+b)
# Out:
# 11
