# %% [markdown]
# <a href="https://colab.research.google.com/github/Maruf-shiab/Basic_python/blob/main/data_analytics_1_june.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")

# %%
print("""hello World
this is my first program Python
I hope i Complete The Course """)

# %%
a="Hello world"
print(a)

# %%
a = input("Enter a number")
print(a)

# %%
name='john'
age=23
type(name)
type(age)

# %%
a=12
